# %%
import plotly.express as px

import pandas as pd
df = pd.read_excel('C:/Users/WTK Agro/Desktop/Pareceres/Concluído/Em análise/ZR ATACADISTA E DISTRIBUIDOR LTDA/1.xlsx')

df.head()
# Out:
#   Tabela 6903 - Índice de Preços ao Produtor, por tipo de índice, indústria geral, indústrias extrativas e indústrias de transformação e atividades (dezembro de 2018 = 100)  \
# 0  Variável - IPP - Número-índice (dezembro de 20...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                             Brasil
#
#                                           Unnamed: 1      Unnamed: 2  \
# 0                                                NaN             NaN
# 1  Indústria geral, indústrias extrativas e indús...             NaN
# 2                                    Indústria Geral             NaN
# 3                                       janeiro 2018  fevereiro 2018
# 4                                           91.63578        91.98513
#
#    Unnamed: 3  Unnamed: 4 Unnamed: 5  Unnamed: 6  Unnamed: 7   Unnamed: 8  \
# ...

# %%
df.loc[df[‘Tabela 6903 - Índice de Preços ao Produtor, por tipo de índice, indústria geral, indústrias extrativas e indústrias de transformacao e atividades (dezembro de 2018 = 100)’] =='Brasil']
# Out:
#   File "<ipython-input-10-0bcf9645496f>", line 1
#     df.loc[df[‘Tabela 6903 - Índice de Preços ao Produtor, por tipo de índice, indústria geral, indústrias extrativas e indústrias de transformacao e atividades (dezembro de 2018 = 100)’] =='Brasil']
#                     ^
# SyntaxError: invalid character in identifier
