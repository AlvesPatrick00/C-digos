# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
url_covid = "https://s3-sa-east-1.amazonaws.com/ckan.saude.gov.br/Leitos/2021-11-09/esus-vepi.LeitoOcupacao.csv?raw=true"
corona = pd.read_csv(url_covid, sep=',', error_bad_lines=False, index_col=False, dtype='unicode') #Ajeitando o erro de low memory

# %%
corona.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222808 entries, 0 to 1222807
# Data columns (total 21 columns):
#  #   Column                 Non-Null Count    Dtype
# ---  ------                 --------------    -----
#  0   _id                    1222808 non-null  object
#  1   dataNotificacao        1222802 non-null  object
#  2   cnes                   1222758 non-null  object
#  3   ocupacaoSuspeitoCli    1015081 non-null  object
#  4   ocupacaoSuspeitoUti    1015081 non-null  object
#  5   ocupacaoConfirmadoCli  1015082 non-null  object
#  6   ocupacaoConfirmadoUti  1015082 non-null  object
#  7   saidaSuspeitaObitos    1222686 non-null  object
#  8   saidaSuspeitaAltas     1222698 non-null  object
#  9   saidaConfirmadaObitos  1222790 non-null  object
#  10  saidaConfirmadaAltas   1222789 non-null  object
#  11  origem                 1222808 non-null  object
#  12  _p_usuario             1222808 non-null  object
#  13  estadoNotificacao      1222808 non-null  object
# ...

# %%
corona.columns
# Out:
# Index(['_id', 'dataNotificacao', 'cnes', 'ocupacaoSuspeitoCli',
#        'ocupacaoSuspeitoUti', 'ocupacaoConfirmadoCli', 'ocupacaoConfirmadoUti',
#        'saidaSuspeitaObitos', 'saidaSuspeitaAltas', 'saidaConfirmadaObitos',
#        'saidaConfirmadaAltas', 'origem', '_p_usuario', 'estadoNotificacao',
#        'municipioNotificacao', 'estado', 'municipio', 'excluido', 'validado',
#        '_created_at', '_updated_at'],
#       dtype='object')

# %%
corona1 = corona [["estado", "municipio", "dataNotificacao", "ocupacaoConfirmadoUti"]] #Filtro

corona1.head()
# Out:
#               estado       municipio           dataNotificacao  \
# 0     Santa Catarina         Itapema  2020-04-14T03:00:00.000Z
# 1     Rio de Janeiro  Rio de Janeiro  2020-04-15T03:00:00.000Z
# 2     Rio de Janeiro         Niterói  2020-04-15T14:57:16.255Z
# 3              Ceará   Várzea Alegre  2020-03-24T03:00:00.000Z
# 4  Rio Grande do Sul       Encantado  2020-04-01T03:00:00.000Z
#
#   ocupacaoConfirmadoUti
# 0                     0
# 1                     0
# 2                     2
# 3                     0
# 4                     0

# %%
corona1["dataNotificacao"].str[:10]
corona1
# Out:
#                     estado           municipio           dataNotificacao  \
# 0           Santa Catarina             Itapema  2020-04-14T03:00:00.000Z
# 1           Rio de Janeiro      Rio de Janeiro  2020-04-15T03:00:00.000Z
# 2           Rio de Janeiro             Niterói  2020-04-15T14:57:16.255Z
# 3                    Ceará       Várzea Alegre  2020-03-24T03:00:00.000Z
# 4        Rio Grande do Sul           Encantado  2020-04-01T03:00:00.000Z
# ...                    ...                 ...                       ...
# 1222803              Ceará             Aracati  2021-11-09T03:00:28.674Z
# 1222804         Pernambuco             Cabrobó  2021-11-09T03:00:43.341Z
# 1222805              Ceará  Tabuleiro do Norte  2021-11-09T03:00:04.716Z
# 1222806           Maranhão            Timbiras  2021-11-09T03:00:08.572Z
# 1222807              Ceará           Fortaleza  2021-11-09T03:00:28.768Z
#
#         ocupacaoConfirmadoUti
# 0                           0
# ...

# %%
corona1 = corona1.fillna("0")
corona1
# Out:
#                     estado           municipio           dataNotificacao  \
# 0           Santa Catarina             Itapema  2020-04-14T03:00:00.000Z
# 1           Rio de Janeiro      Rio de Janeiro  2020-04-15T03:00:00.000Z
# 2           Rio de Janeiro             Niterói  2020-04-15T14:57:16.255Z
# 3                    Ceará       Várzea Alegre  2020-03-24T03:00:00.000Z
# 4        Rio Grande do Sul           Encantado  2020-04-01T03:00:00.000Z
# ...                    ...                 ...                       ...
# 1222803              Ceará             Aracati  2021-11-09T03:00:28.674Z
# 1222804         Pernambuco             Cabrobó  2021-11-09T03:00:43.341Z
# 1222805              Ceará  Tabuleiro do Norte  2021-11-09T03:00:04.716Z
# 1222806           Maranhão            Timbiras  2021-11-09T03:00:08.572Z
# 1222807              Ceará           Fortaleza  2021-11-09T03:00:28.768Z
#
#         ocupacaoConfirmadoUti
# 0                           0
# ...

# %%
datainicial = "2021-01-01"
corona2 = corona1[(corona1["municipio"] == "Florianópolis") & (corona1["dataNotificacao"] > datainicial)] # "&" = E; "|" 
corona2.head(10)
# Out:
#                 estado      municipio           dataNotificacao  \
# 545619  Santa Catarina  Florianópolis  2021-01-01T03:00:00.000Z
# 545657  Santa Catarina  Florianópolis  2021-01-01T03:00:50.044Z
# 547253  Santa Catarina  Florianópolis  2021-01-02T03:00:00.000Z
# 547424  Santa Catarina  Florianópolis  2021-01-01T03:00:00.000Z
# 547442  Santa Catarina  Florianópolis  2021-01-02T03:00:46.578Z
# 547471  Santa Catarina  Florianópolis  2021-01-01T03:00:00.000Z
# 547472  Santa Catarina  Florianópolis  2021-01-02T03:00:34.780Z
# 548970  Santa Catarina  Florianópolis  2021-01-03T03:00:44.268Z
# 549059  Santa Catarina  Florianópolis  2021-01-03T03:00:56.548Z
# 550575  Santa Catarina  Florianópolis  2021-01-04T03:00:01.883Z
#
#        ocupacaoConfirmadoUti
# 545619                    21
# 545657                     7
# 547253                    21
# 547424                    24
# 547442                     8
# 547471                     7
# 547472                     7
# ...

# %%
#corona1.loc[(corona1["ocupacaoConfirmadoUti"].between(10, 1e4))]

# %%
#corona1.query("ocupacaoConfirmadoUti > 10")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-10-e9c6f0aa9e6c> in <module>
# ----> 1 corona1.query("ocupacaoConfirmadoUti > 10")
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in query(self, expr, inplace, **kwargs)
#    3467         kwargs["level"] = kwargs.pop("level", 0) + 1
#    3468         kwargs["target"] = None
# -> 3469         res = self.eval(expr, **kwargs)
#    3470
#    3471         try:
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in eval(self, expr, inplace, **kwargs)
#    3597         kwargs["resolvers"] = kwargs.get("resolvers", ()) + tuple(resolvers)
#    3598
# -> 3599         return _eval(expr, inplace=inplace, **kwargs)
#    3600
#    3601     def select_dtypes(self, include=None, exclude=None) -> DataFrame:
#
# ...
